# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('churn.csv')

# %%
data.head()
# Out:
#    Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  Intl_Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ_Calls Churn Intl_Plan Vmail_Plan  ...  Day_Charge  Eve_Calls  \
# 0               1    no        no        yes  ...       45.07         99
# 1               1    no        no        yes  ...       27.47        103
# 2               0    no        no         no  ...       41.38        110
# 3               2    no       yes         no  ...       50.90         88
# 4               3    no       yes         no  ...       28.34        122
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account_Length  3333 non-null   int64
#  1   Vmail_Message   3333 non-null   int64
#  2   Day_Mins        3333 non-null   float64
#  3   Eve_Mins        3333 non-null   float64
#  4   Night_Mins      3333 non-null   float64
#  5   Intl_Mins       3333 non-null   float64
#  6   CustServ_Calls  3333 non-null   int64
#  7   Churn           3333 non-null   object
#  8   Intl_Plan       3333 non-null   object
#  9   Vmail_Plan      3333 non-null   object
#  10  Day_Calls       3333 non-null   int64
#  11  Day_Charge      3333 non-null   float64
#  12  Eve_Calls       3333 non-null   int64
#  13  Eve_Charge      3333 non-null   float64
#  14  Night_Calls     3333 non-null   int64
#  15  Night_Charge    3333 non-null   float64
#  16  Intl_Calls      3333 non-null   int64
# ...

# %%
data.isna().sum()
# Out:
# Account_Length    0
# Vmail_Message     0
# Day_Mins          0
# Eve_Mins          0
# Night_Mins        0
# Intl_Mins         0
# CustServ_Calls    0
# Churn             0
# Intl_Plan         0
# Vmail_Plan        0
# Day_Calls         0
# Day_Charge        0
# Eve_Calls         0
# Eve_Charge        0
# Night_Calls       0
# Night_Charge      0
# Intl_Calls        0
# Intl_Charge       0
# State             0
# Area_Code         0
# Phone             0
# dtype: int64

# %%
data['Churn'].value_counts()
# Out:
# no     2850
# yes     483
# Name: Churn, dtype: int64

# %%
data['Churn'].value_counts(normalize=True)
# Out:
# no     0.855086
# yes    0.144914
# Name: Churn, dtype: float64

# %%
data.shape
# Out:
# (3333, 21)

# %%
data.columns
# Out:
# Index(['Account_Length', 'Vmail_Message', 'Day_Mins', 'Eve_Mins', 'Night_Mins',
#        'Intl_Mins', 'CustServ_Calls', 'Churn', 'Intl_Plan', 'Vmail_Plan',
#        'Day_Calls', 'Day_Charge', 'Eve_Calls', 'Eve_Charge', 'Night_Calls',
#        'Night_Charge', 'Intl_Calls', 'Intl_Charge', 'State', 'Area_Code',
#        'Phone'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Account_Length  Vmail_Message     Day_Mins     Eve_Mins   Night_Mins  \
# count     3333.000000    3333.000000  3333.000000  3333.000000  3333.000000
# mean       101.064806       8.099010   179.775098   200.980348   200.872037
# std         39.822106      13.688365    54.467389    50.713844    50.573847
# min          1.000000       0.000000     0.000000     0.000000    23.200000
# 25%         74.000000       0.000000   143.700000   166.600000   167.000000
# 50%        101.000000       0.000000   179.400000   201.400000   201.200000
# 75%        127.000000      20.000000   216.400000   235.300000   235.300000
# max        243.000000      51.000000   350.800000   363.700000   395.000000
#
#          Intl_Mins  CustServ_Calls    Day_Calls   Day_Charge    Eve_Calls  \
# count  3333.000000     3333.000000  3333.000000  3333.000000  3333.000000
# mean     10.237294        1.562856   100.435644    30.562307   100.114311
# ...

# %%
data.nunique()
# Out:
# Account_Length     212
# Vmail_Message       46
# Day_Mins          1667
# Eve_Mins          1611
# Night_Mins        1591
# Intl_Mins          162
# CustServ_Calls      10
# Churn                2
# Intl_Plan            2
# Vmail_Plan           2
# Day_Calls          119
# Day_Charge        1667
# Eve_Calls          123
# Eve_Charge        1440
# Night_Calls        120
# Night_Charge       933
# Intl_Calls          21
# Intl_Charge        162
# State               51
# Area_Code            3
# Phone             3333
# dtype: int64

# %%
data.groupby("Churn")["Day_Charge"].mean()
# Out:
# Churn
# no     29.780421
# yes    35.175921
# Name: Day_Charge, dtype: float64

# %%
data.dtypes
# Out:
# Account_Length      int64
# Vmail_Message       int64
# Day_Mins          float64
# Eve_Mins          float64
# Night_Mins        float64
# Intl_Mins         float64
# CustServ_Calls      int64
# Churn              object
# Intl_Plan          object
# Vmail_Plan         object
# Day_Calls           int64
# Day_Charge        float64
# Eve_Calls           int64
# Eve_Charge        float64
# Night_Calls         int64
# Night_Charge      float64
# Intl_Calls          int64
# Intl_Charge       float64
# State              object
# Area_Code           int64
# Phone              object
# dtype: object

# %%
#'State', 'Area_Code','Phone' not required. so drop it
data=data.drop(['State', 'Area_Code','Phone'],axis=1)

# %%
num_cols=['Account_Length', 'Vmail_Message', 'Day_Mins', 'Eve_Mins', 'Night_Mins',
       'Intl_Mins', 'CustServ_Calls','Day_Calls', 'Day_Charge', 'Eve_Calls', 'Eve_Charge', 'Night_Calls',
       'Night_Charge', 'Intl_Calls','Intl_Charge']

# %%
data[num_cols]
# Out:
#       Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  \
# 0                128             25     265.1     197.4       244.7
# 1                107             26     161.6     195.5       254.4
# 2                137              0     243.4     121.2       162.6
# 3                 84              0     299.4      61.9       196.9
# 4                 75              0     166.7     148.3       186.9
# ...              ...            ...       ...       ...         ...
# 3328             192             36     156.2     215.5       279.1
# 3329              68              0     231.1     153.4       191.3
# 3330              28              0     180.8     288.8       191.9
# 3331             184              0     213.8     159.6       139.2
# 3332              74             25     234.4     265.9       241.4
#
#       Intl_Mins  CustServ_Calls  Day_Calls  Day_Charge  Eve_Calls  Eve_Charge  \
# ...

# %%
#sns.pairplot(data[num_cols])

# %%
data[num_cols].corr()
# Out:
#                 Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  \
# Account_Length        1.000000      -0.004628  0.006216 -0.006757   -0.008955
# Vmail_Message        -0.004628       1.000000  0.000778  0.017562    0.007681
# Day_Mins              0.006216       0.000778  1.000000  0.007043    0.004323
# Eve_Mins             -0.006757       0.017562  0.007043  1.000000   -0.012584
# Night_Mins           -0.008955       0.007681  0.004323 -0.012584    1.000000
# Intl_Mins             0.009514       0.002856 -0.010155 -0.011035   -0.015207
# CustServ_Calls       -0.003796      -0.013263 -0.013423 -0.012985   -0.009288
# Day_Calls             0.038470      -0.009548  0.006750 -0.021451    0.022938
# Day_Charge            0.006214       0.000776  1.000000  0.007050    0.004324
# Eve_Calls             0.019260      -0.005864  0.015769 -0.011430   -0.002093
# Eve_Charge           -0.006745       0.017578  0.007029  1.000000   -0.012592
# ...

# %% [markdown]
# The columns are not correlated. As we use principal component analysis, the model acuracy decreases significantly. So PCA is not used.

# %%
data[num_cols].shape
# Out:
# (3333, 15)

# %%
#from sklearn.decomposition import PCA
#pc = PCA(n_components=11)
#pc_data = pc.fit_transform(data[num_cols])

# %%
#data_pca = pd.DataFrame(pc_data, columns= ['PC'+str(i) for i in range(1,12)])

# %%
#sum(pc.explained_variance_ratio_ *100)

# %%
#data_pca.corr().round(2)

# %%
#data_pca['PC1']

# %%
#data['pca_feature'] = data_pca['PC1'].values

# %%
#data

# %%
#data = data.drop(data[num_cols],axis=1)

# %%
#data

# %%
x = data.drop("Churn",axis=1)

y = data['Churn']

# %%
x
# Out:
#       Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  \
# 0                128             25     265.1     197.4       244.7
# 1                107             26     161.6     195.5       254.4
# 2                137              0     243.4     121.2       162.6
# 3                 84              0     299.4      61.9       196.9
# 4                 75              0     166.7     148.3       186.9
# ...              ...            ...       ...       ...         ...
# 3328             192             36     156.2     215.5       279.1
# 3329              68              0     231.1     153.4       191.3
# 3330              28              0     180.8     288.8       191.9
# 3331             184              0     213.8     159.6       139.2
# 3332              74             25     234.4     265.9       241.4
#
#       Intl_Mins  CustServ_Calls Intl_Plan Vmail_Plan  Day_Calls  Day_Charge  \
# ...

# %%
#one hot encoding
x=pd.get_dummies(x)
x
# Out:
#       Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  \
# 0                128             25     265.1     197.4       244.7
# 1                107             26     161.6     195.5       254.4
# 2                137              0     243.4     121.2       162.6
# 3                 84              0     299.4      61.9       196.9
# 4                 75              0     166.7     148.3       186.9
# ...              ...            ...       ...       ...         ...
# 3328             192             36     156.2     215.5       279.1
# 3329              68              0     231.1     153.4       191.3
# 3330              28              0     180.8     288.8       191.9
# 3331             184              0     213.8     159.6       139.2
# 3332              74             25     234.4     265.9       241.4
#
#       Intl_Mins  CustServ_Calls  Day_Calls  Day_Charge  Eve_Calls  Eve_Charge  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                   test_size=0.2,random_state=134)

# %%
x_train.shape, x_test.shape
# Out:
# ((2666, 19), (667, 19))

# %%
y_train.shape, y_test.shape
# Out:
# ((2666,), (667,))

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
x_train.loc[:,num_cols] = ms.fit_transform(x_train[num_cols])
x_test.loc[:,num_cols] = ms.fit_transform(x_test[num_cols])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score, confusion_matrix,mean_squared_error

# %%
# logistic regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8530734632683659

# %%
## knn
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8920539730134932

# %%
#### decision trees  
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.815592203898051

# %%
##### voting classifier
from sklearn.ensemble import VotingClassifier
lr = LogisticRegression()
knn = KNeighborsClassifier(n_neighbors=13)
sv = SVC()
classifiers = [("log_reg",lr),("knn",knn),("svm",sv)]

vc = VotingClassifier(estimators=classifiers)
vc.fit(x_train, y_train)
y_pred = vc.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8950524737631185

# %%
####### random forest classifier
from sklearn.ensemble import RandomForestClassifier
rt = RandomForestClassifier()
rt.fit(x_train, y_train)
y_pred = rt.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8995502248875562

# %%
#fine tuning the parameters using the gridsearchCV.

# %%
#random forest classifier is used. Since it produces best result
rt.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define a grid of hyperparameter 'params_rt' 
params_rt = {'n_estimators': [100,200,300],
             'criterion': ['gini','entropy'],
             'max_depth': [8, 16,32],           
             'max_features': ['log2', 'sqrt']}

# %%
grid_rt = GridSearchCV(estimator=rt, param_grid=params_rt, cv = 5, scoring="accuracy")

# %%
grid_rt.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [8, 16, 32],
#                          'max_features': ['log2', 'sqrt'],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
grid_rt.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 32,
#  'max_features': 'sqrt',
#  'n_estimators': 600}

# %%
grid_rt.best_score_ #accuracy has increased
# Out:
# 0.9538637210054036

# %%
best_model = grid_rt.best_estimator_

# %%
y_pred = best_model.predict(x_test)

# %%
print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Weighted Precision: 0.91
# Weighted Recall: 0.90
# Weighted F1-score: 0.90
